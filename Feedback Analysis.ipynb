# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import re
import sklearn
# %matplotlib inline

# %%
text = pd.read_table("imdb_labelled.txt", sep = '\t', names = ['Review', 'Rating'])
amazon = pd.read_table("amazon_cells_labelled.txt", sep = '\t', names = ['Review', 'Rating'])
yelp = pd.read_table("yelp_labelled.txt", sep = '\t', names = ['Review', 'Rating'])

# %%
text
# Out:
#                                                 Review  Rating
# 0    A very, very, very slow-moving, aimless movie ...       0
# 1    Not sure who was more lost - the flat characte...       0
# 2    Attempting artiness with black & white and cle...       0
# 3         Very little music or anything to speak of.         0
# 4    The best scene in the movie was when Gerardo i...       1
# 5    The rest of the movie lacks art, charm, meanin...       0
# 6                                  Wasted two hours.         0
# 7    Saw the movie today and thought it was a good ...       1
# 8                                 A bit predictable.         0
# 9    Loved the casting of Jimmy Buffet as the scien...       1
# 10                And those baby owls were adorable.         1
# 11   The movie showed a lot of Florida at it's best...       1
# 12   The Songs Were The Best And The Muppets Were S...       1
# 13                                   It Was So Cool.         1
# ...

# %%
text['positive_words'] = text.Review.str.contains('I lov*|I lik*|it was great*|', case = False, regex = True)

# %%
text['negative_words'] = text.Review.str.contains('hate*|terribl*|wors*|bad|but|lame|waste*|never again|too',
                                                  case = False, regex = True)

# %%
text.where((text['positive_words'] == True) & (text['Rating'] == 1)).dropna()
# Out:
#                                                 Review  Rating  \
# 4    The best scene in the movie was when Gerardo i...     1.0
# 7    Saw the movie today and thought it was a good ...     1.0
# 9    Loved the casting of Jimmy Buffet as the scien...     1.0
# 10                And those baby owls were adorable.       1.0
# 11   The movie showed a lot of Florida at it's best...     1.0
# 12   The Songs Were The Best And The Muppets Were S...     1.0
# 13                                   It Was So Cool.       1.0
# 14   This is a very "right on case" movie that deli...     1.0
# 16   This review is long overdue, since I consider ...     1.0
# 17   I'll put this gem up against any movie in term...     1.0
# 18   It's practically perfect in all of them  a tr...     1.0
# 20   This if the first movie I've given a 10 to in ...     1.0
# 21   If there was ever a movie that needed word-of-...     1.0
# 22   Overall, the film is interesting and thought-p...     1.0
# ...

# %%
text.where((text['positive_words'] == True) & (text['Rating'] == 0)).dropna()
# Out:
#                                                 Review  Rating  \
# 0    A very, very, very slow-moving, aimless movie ...     0.0
# 1    Not sure who was more lost - the flat characte...     0.0
# 2    Attempting artiness with black & white and cle...     0.0
# 3         Very little music or anything to speak of.       0.0
# 5    The rest of the movie lacks art, charm, meanin...     0.0
# 6                                  Wasted two hours.       0.0
# 8                                 A bit predictable.       0.0
# 15   It had some average acting from the main perso...     0.0
# 19    The structure of this film is easily the most...     0.0
# 30                       The problem was the script.       0.0
# 31                                It was horrendous.       0.0
# 32     There was NOTHING believable about it at all.       0.0
# 33   The only suspense I was feeling was the frustr...     0.0
# 40   Frankly, after Cotton club and Unfaithful, it ...     0.0
# ...

# %% [markdown]
#  I tried to group a few common positive/negative words into some regex expressions - although this is an amazingly more complicated problem than it seems at first.  I was only able to get a small percentage of accurate predictions, but it was a majority that was correct.  Based on the models and outcomes below, it looks like this model gets the best results with Yelp.

# %%
# Applying the model above to the different files/contexts:

amazon['positive_words'] = text.Review.str.contains('I lov*|I lik*|it was great*|', case = False, regex = True)
amazon['negative_words'] = text.Review.str.contains('hate*|terribl*|wors*|bad|but|lame|waste*|never again|too',
                                                  case = False, regex = True)

yelp['positive_words'] = text.Review.str.contains('I lov*|I lik*|it was great*|', case = False, regex = True)
yelp['negative_words'] = text.Review.str.contains('hate*|terribl*|wors*|bad|but|lame|waste*|never again|too',
                                                  case = False, regex = True)

# %%
amazon_positive = amazon.where((amazon['positive_words'] == True) & (amazon['Rating'] == 1)).dropna()
amazon_negative = amazon.where((amazon['positive_words'] == True) & (amazon['Rating'] == 0)).dropna()

# %%
yelp_positive = yelp.where((yelp['positive_words'] == True) & (yelp['Rating'] == 1)).dropna()
yelp_negative = yelp.where((yelp['positive_words'] == True) & (yelp['Rating'] == 0)).dropna()

# %%
print("Correctly labelled Amazon reviews: Correct Positives {}, False Positivies {}".format(
    amazon_positive.count(), amazon_negative.count()))
# Out:
# Correctly labelled Amazon reviews: Correct Positives Review            384
# Rating            384
# positive_words    384
# negative_words    384
# dtype: int64, False Positivies Review            364
# Rating            364
# positive_words    364
# negative_words    364
# dtype: int64

# %%
print("Correctly labelled Yelp reviews: Correct Positives {}, False Positivies {}".format(
    yelp_positive.count(), yelp_negative.count()))
# Out:
# Correctly labelled Yelp reviews: Correct Positives Review            422
# Rating            422
# positive_words    422
# negative_words    422
# dtype: int64, False Positivies Review            326
# Rating            326
# positive_words    326
# negative_words    326
# dtype: int64

# %%
text.keys()
# Out:
# Index(['Review', 'Rating', 'positive_words', 'negative_words'], dtype='object')

# %%
from sklearn.naive_bayes import BernoulliNB

bnb = BernoulliNB()

text_data = text[['positive_words','negative_words']]
text_target = [text[text['Rating'] == 1]]

bnb.fit(text_data, text_target)
y_pred = bnb.predict(text_target)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /anaconda/lib/python3.6/site-packages/numpy/core/fromnumeric.py in shape(a)
#    1651     try:
# -> 1652         result = a.shape
#    1653     except AttributeError:
#
# AttributeError: 'list' object has no attribute 'shape'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-dc2aba16083a> in <module>()
#       6 text_target = [text[text['Rating'] == 1]]
#       7
# ----> 8 bnb.fit(text_data, text_target)
#       9 y_pred = bnb.predict(text_target)
#
# /anaconda/lib/python3.6/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     577             Returns self.
#     578         """
# --> 579         X, y = check_X_y(X, y, 'csr')
#     580         _, n_features = X.shape
#     581
#
# ...
